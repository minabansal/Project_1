# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from gr_key import gr_key
from nyt_key import nyt_key

# %%
nyt_url = "https://api.nytimes.com/svc/books/v3//lists/2019-01-20/hardcover-fiction.json?api-key=" + nyt_key

bestsellers = requests.get(nyt_url).json()
print(json.dumps(bestsellers, indent=4,sort_keys=True))
# Out:
# {
#     "copyright": "Copyright (c) 2019 The New York Times Company.  All Rights Reserved.",
#     "last_modified": "2019-01-09T23:38:02-05:00",
#     "num_results": 15,
#     "results": {
#         "bestsellers_date": "2019-01-05",
#         "books": [
#             {
#                 "age_group": "",
#                 "amazon_product_url": "https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20",
#                 "article_chapter_link": "",
#                 "asterisk": 0,
#                 "author": "Delia Owens",
#                 "book_image": "https://s1.nyt.com/du/books/images/9780735219090.jpg",
#                 "book_image_height": 495,
#                 "book_image_width": 328,
#                 "book_review_link": "",
#                 "buy_links": [
#                     {
#                         "name": "Local Booksellers",
#                         "url": "http://www.indiebound.org/book/9780735219090?aff=NYT"
#                     },
# ...

# %%
pprint()
